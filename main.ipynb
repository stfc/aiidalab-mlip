# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
# document.title="AiiDAlab MLIP"

# %%
# %%capture
from aiida import load_profile

load_profile();

# %%
from aiidalab_mlip.main import MainApp

app = MainApp()
# Out:
# MainAppView(children=(VBox(children=(HTML(value='\n            <div class="app-container logo" style="text-ali…
