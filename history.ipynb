# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(line) {
#     return false;
# }
# document.title = "AiiDAlab MLIP"

# %%
# %%capture
from aiida import load_profile
load_profile();

# %%
from aiidalab_mlip.history import HistoryApp
app = HistoryApp()
